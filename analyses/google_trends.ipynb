# %%
from pytrends.request import TrendReq
import pandas as pd

pytrends = TrendReq(hl='en-US', tz=360)

# %%
kw_list = ['Suicide']
pytrends.build_payload(kw_list, cat=0, timeframe='today 5-y', geo='US', gprop='news')

df = pytrends.interest_over_time()
df
# Out:
#             Suicide  isPartial
# date
# 2017-11-19       29      False
# 2017-11-26       31      False
# 2017-12-03       33      False
# 2017-12-10       35      False
# 2017-12-17       29      False
# ...             ...        ...
# 2022-10-09       16      False
# 2022-10-16       26      False
# 2022-10-23       18      False
# 2022-10-30       19      False
# 2022-11-06       23       True
#
# [260 rows x 2 columns]

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# Load an example dataset with long-form data
fmri = sns.load_dataset("fmri")

# Plot the responses for different events and regions
sns.lineplot(x="date", y="Suicide", data=df)
# Out:
# <AxesSubplot:xlabel='date', ylabel='Suicide'>
